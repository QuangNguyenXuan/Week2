# %% [markdown]
# ## **1. Import các thư viện cần thiết**

# %%
import os   
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **2. Chuẩn bị dữ liệu**

# %%
# Khai báo hàm Windowing (dùng để tạo các cặp X, y cho time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset):
    features = [] # Khai báo list dùng để lưu trữ các X
    labels = [] # Khai báo list dùng để lưu trữ các y

    window_size = input_size + offset # Tính kích thước của window

    # Nếu df_end_idx = chỉ mục cuối cùng bảng dữ liệu, cần phải dời xuống 1 khoảng = window size 
    if df_end_idx == None:
        df_end_idx = len(df) - window_size 
    
    # Duyệt qua từng mẫu dữ liệu
    for idx in range(df_start_idx, df_end_idx):
        feature_end_idx = idx + input_size # Tính chỉ mục kết thúc của X
        label_start_idx = idx + window_size - label_size # Tính chỉ mục bắt đầu của y

        feature = df[idx:feature_end_idx] # Lấy X
        label = df[label_start_idx:(idx+window_size)] # Lấy y

        features.append(feature) 
        labels.append(label)

    # Chuyển list thành np.ndarrray
    features = np.expand_dims(np.array(features), -1) 
    labels = np.array(labels)

    return features, labels

# %%
univariate_df = pd.read_csv('temp.csv')
univariate_df = univariate_df['Temperature (C)']
univariate_df.head(7)
# Out:
# 0    9.472222
# 1    9.355556
# 2    9.377778
# 3    8.288889
# 4    8.755556
# 5    9.222222
# 6    7.733333
# Name: Temperature (C), dtype: float64

# %%
univariate_df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>], dtype=object)

# %%
INPUT_SIZE = 20 # Dùng `input_size` giờ trước
LABEL_SIZE = 6 # Để dự đoán nhiệt độ trong `label_size` giờ
OFFSET = 6 # Vào khoảng `offset` giờ tiếp theo 
BATCH_SIZE = 32

# %%
dataset_length = len(univariate_df) # Số lượng mẫu dữ liệu trong DataFrame
TRAIN_SIZE = 0.7 # Tỉ lệ kích thước tập train
VAL_SIZE = 0.2 # Tỉ lệ kích thước tập val
# Đổi tỉ lệ thành chỉ mục
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length) 
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# Khởi tạo X, y cho tập train
X_train, y_train = slicing_window(univariate_df, 
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET)

# Khởi tạo X, y cho tập val
X_val, y_val = slicing_window(univariate_df, 
                                  df_start_idx=TRAIN_END_IDX,
                                  df_end_idx=VAL_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET)

# Khởi tạo X, y cho tập test
X_test, y_test = slicing_window(univariate_df, 
                                  df_start_idx=VAL_END_IDX,
                                  df_end_idx=None,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET)

# %%
# Khởi tạo tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Cấu hình các tham số tối ưu cho việc đọc dữ liệu
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **3. Xây dựng mô hình**

# %%
# Khai báo normalization layer
normalize_layer = tf.keras.layers.Normalization(axis=-1)
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Xây dựng hàm khởi tạo model
def build_model(input_shape):
    model = tf.keras.Sequential([
        # Input layer (nhận vào 1 string)
        tf.keras.Input(shape=input_shape, name='input_layer'),
        normalize_layer,

        # RNN Layer 1 
        tf.keras.layers.SimpleRNN(16, 
                            return_sequences=True, 
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='rnn_layer_1'),      

        # RNN Layer 2
        tf.keras.layers.SimpleRNN(16, 
                            return_sequences=True, 
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='rnn_layer_2'),               
                    
        # RNN Layer 3
        tf.keras.layers.SimpleRNN(16, 
                            return_sequences=False, 
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='rnn_layer_3'),      
                                
        # Output Layer
        tf.keras.layers.Dense(LABEL_SIZE, 
                              kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                              name='output_layer') 
    ],
    name='rnn_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:] 
model = build_model(INPUT_SHAPE)
model.summary()
# Out:
# Model: "rnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 20, 1)            3
#  n)
#
#  rnn_layer_1 (SimpleRNN)     (None, 20, 16)            288
#
#  rnn_layer_2 (SimpleRNN)     (None, 20, 16)            528
#
#  rnn_layer_3 (SimpleRNN)     (None, 16)                528
#
#  output_layer (Dense)        (None, 6)                 102
#
# =================================================================
# Total params: 1,449
# Trainable params: 1,446
# Non-trainable params: 3
# _________________________________________________________________

# %% [markdown]
# ## **4. Cấu hình mô hình**

# %%
# Khai báo một số giá trị siêu tham số
EPOCHS = 35
LR = 1e-3

# %%
# Cấu hình một số thông tin cho mô hình
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Sử dụng optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Sử dụng hàm loss Mean Squared Error
)

# %% [markdown]
# ## **5. Huấn luyện mô hình**

# %%
history = model.fit(train_ds, 
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/35
# 2110/2110 [==============================] - 52s 23ms/step - loss: 78.0287 - val_loss: 22.7768
# Epoch 2/35
# 2110/2110 [==============================] - 45s 21ms/step - loss: 16.9443 - val_loss: 12.7235
# Epoch 3/35
# 2110/2110 [==============================] - 44s 21ms/step - loss: 10.9776 - val_loss: 9.5710
# Epoch 4/35
# 2110/2110 [==============================] - 45s 21ms/step - loss: 9.2069 - val_loss: 8.7139
# Epoch 5/35
# 2110/2110 [==============================] - 41s 19ms/step - loss: 8.3584 - val_loss: 7.7052
# Epoch 6/35
# 2110/2110 [==============================] - 43s 20ms/step - loss: 7.8724 - val_loss: 7.1876
# Epoch 7/35
# 2110/2110 [==============================] - 41s 20ms/step - loss: 7.5702 - val_loss: 6.9462
# Epoch 8/35
# 2110/2110 [==============================] - 42s 20ms/step - loss: 7.3374 - val_loss: 6.9007
# Epoch 9/35
# 2110/2110 [==============================] - 46s 22ms/step - loss: 7.1596 - val_loss: 6.8766
# Epoch 10/35
# 2110/2110 [==============================] - 42s 20ms/step - loss: 7.0286 - val_loss: 6.8153
# Epoch 11/35
# 2110/2110 [==============================] - 39s 19ms/step - loss: 6.9299 - val_loss: 6.6335
# Epoch 12/35
# 2110/2110 [==============================] - 43s 20ms/step - loss: 6.8339 - val_loss: 6.6200
# Epoch 13/35
# 2110/2110 [==============================] - 43s 20ms/step - loss: 6.7501 - val_loss: 6.5530
# Epoch 14/35
# 2110/2110 [==============================] - 39s 19ms/step - loss: 6.6839 - val_loss: 6.4582
# Epoch 15/35
# 2110/2110 [==============================] - 42s 20ms/step - loss: 6.6218 - val_loss: 6.3603
# Epoch 16/35
# 2110/2110 [==============================] - 42s 20ms/step - loss: 6.5683 - val_loss: 6.2305
# Epoch 17/35
# 2110/2110 [==============================] - 44s 21ms/step - loss: 6.5227 - val_loss: 6.1384
# Epoch 18/35
# 2110/2110 [==============================] - 45s 21ms/step - loss: 6.4804 - val_loss: 6.0817
# Epoch 19/35
# 2110/2110 [==============================] - 45s 21ms/step - loss: 6.4423 - val_loss: 6.0418
# Epoch 20/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.4049 - val_loss: 6.0241
# Epoch 21/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.3699 - val_loss: 6.0099
# Epoch 22/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.3374 - val_loss: 6.0085
# Epoch 23/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.3021 - val_loss: 6.0007
# Epoch 24/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.2689 - val_loss: 5.9741
# Epoch 25/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.2385 - val_loss: 5.9564
# Epoch 26/35
# 2110/2110 [==============================] - 48s 23ms/step - loss: 6.2113 - val_loss: 5.9377
# Epoch 27/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1854 - val_loss: 5.9021
# Epoch 28/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1638 - val_loss: 5.8775
# Epoch 29/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1458 - val_loss: 5.8285
# Epoch 30/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1302 - val_loss: 5.8007
# Epoch 31/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1167 - val_loss: 5.7820
# Epoch 32/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.1035 - val_loss: 5.7639
# Epoch 33/35
# 2110/2110 [==============================] - 46s 22ms/step - loss: 6.0879 - val_loss: 5.7504
# Epoch 34/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.0741 - val_loss: 5.7405
# Epoch 35/35
# 2110/2110 [==============================] - 47s 22ms/step - loss: 6.0596 - val_loss: 5.7354

# %% [markdown]
# ## **6. Đánh giá và trực quan hóa**

# %%
# Đánh giá mô hình trên tập test
test_evaluation = model.evaluate(test_ds)
# Out:
# 301/301 [==============================] - 2s 7ms/step - loss: 5.2697

# %%
train_loss = history.history['loss']# Đọc thông tin loss trên tập train
val_loss = history.history['val_loss'] # Đọc thông tin loss trên tập val

plt.figure(figsize=(10, 5)) # Cài đặt kích thước khung ảnh

plt.subplot(1, 2, 1) # Khởi tạo khung ảnh cho training loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Training loss') # Hiển thị title của khung ảnh hiện tại là 'Training Loss'
plt.plot(train_loss, color='red') # Vẽ đường giá trị loss trên tập train qua từng epoch (đường vẽ màu đỏ)

plt.subplot(1, 2, 2) # Khởi tạo khung ảnh cho val loss
plt.xlabel('Epochs') # Hiển thị tên trục hoành là 'Epochs'
plt.ylabel('Loss') # Hiển thị tên trục tung là 'Loss'
plt.title('Validation loss') # Hiển thị title của khung ảnh hiện tại là 'Validation loss'
plt.plot(val_loss, color='orange') # Vẽ đường giá trị loss trên tập val qua từng epoch (đường vẽ màu đỏ)

plt.show() # Hiển thị 2 khung ảnh nhỏ
